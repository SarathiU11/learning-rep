# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("demo").getOrCreate()

# %%
data = [(1,"sarathi",20),
        (2,"arun",21),
        (3,"Priya",22)
        ]
columns = ["id","name","age"]

df = spark.createDataFrame(data,columns)

# %%
df.show()

# %% [markdown]
# id  name      city
# 1   Sarathi   Chennai
# 2   Arun      Coimbatore
# 3   Priya     Madurai
# 4   Kavin     Salem
# 5   John      Trichy

# %%
data =[(1,"Sarathi","Chennai"),
       (2,"Arun","Coimbatore"),
       (3,"Priya","Bangalore"),
       (4,"kavin","salem"),
       (5,"john","trichy")]

columns = ["id","name","city"]

df2 = spark.createDataFrame(data,columns)
df2.show(3)

# %% [markdown]
# | id | name    | salary |
# | -- | ------- | ------ |
# | 1  | Alice   | 50000  |
# | 2  | Bob     | 65000  |
# | 3  | Charlie | 70000  |
# Create the DataFrame.
# Display it with show().
# Print the schema using printSchema().

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("demo").getOrCreate()

data =[(1,"Alice",50000),
       (2,"Bob",60000),
       (3,"Charlie",70000)
       ]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("demo").getOrCreate()

data =[(1,"Alice",50000),
       (2,"Bob",60000),
       (3,"Charlie",70000)
       ]
columns=["id","name","salary"]
df = spark.createDataFrame(data,columns)
df.show()

# %%
df.printSchema()
